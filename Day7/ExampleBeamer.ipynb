# %% [raw]
# ---
# format:
#     beamer:
#         aspectratio: 32
#         navigation: frame
#         theme: Singapore
#         colortheme: seagull
#         innertheme: circles
#
# editor: visual
# warning: false
# error: false
# code-overflow: wrap
# eval: true
#
# title: "Intermediate Data Science"
# subtitle: "Visualization"
# author: "Joanna Bieri <br> DATA201"
# ---

# %% [markdown]
# # You might need to install LaTeX
#
# https://guides.nyu.edu/LaTeX/installation
#
# # Quarto Beamer Options
#
# Each heading separates a slide.
#
# # Quarto Webpage
#
# **Theme Options**
#
# Beamer themes define the overall layout and style of your presentation.
#
# - Singapore
# - AnnArbor
# - Antibes
# - Bergen
# - Berlin
# - Copenhagen
# - Darmstadt
# - Frankfurt
# - Goettingen
# - Hannover
# - Ilmenau
# - Johannesburg
# - Luebeck
# - Malmoe
# - PaloAlto
# - Rochester
# - Szeged
# - Warsaw
#
# # Quarto Webpage
#
# **Colortheme Options**
#
# The colortheme defines the color scheme for your presentation.
#
# - seagull
# - beetle
# - dove
# - crane
# - rose
# - orchid
# - whale
# - whale (light)
# - wolverine
# - seahorse
# - apple
# - structure
# - orange
# - blue
# - default
#
# # Quarto Webpage
#
# **Innertheme Options**
#
# Innerthemes control the appearance of slide elements like blocks, navigation bars, and footers.
#
# - circles (your current choice)
# - rectangles
# - infolines
# - rounded
# - default
#
# # Pretty Equations
#
# ## Equation
#
# $$\frac{dy}{dx} = \sin(x)$$
